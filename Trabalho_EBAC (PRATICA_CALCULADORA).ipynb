# %% [markdown]
# ## CALCULADORA SEM PESQUISAR NADA POR FORA

# %%
# TRABALHO DE PRATÍCA   # PS: Praticar tem sido uma terapia para mim, estou amando isso!.
# no texto eu pedi ajuda ao GPT, pois nao sabia como podia fazer de um jeito que ficasse bom, pois a linha ficou super reta e poluida.
# espero não perder pontos
nome = input('como você se chama calculador?: ')
print('=' * 50)
print(f"Bem-vindo(a) {nome}! Aqui é a Calculadora Calculável, sim, ISSO MESMO: C-A-L-C-U-L-A-V-E-L.\n")
print("Aqui existem duas regras:")
print("- Seus cálculos não podem ultrapassar 99999;")
print("- Você só pode usar as operações (+, -, *, /).\n")
print("Bom cálculo!\n")
print('=' * 50)
num1 = int(input('Digite o valor desejado no calculo: '))
operador = input('Escolha o operador: (+, -, *, /)')
num2 = int(input('Digite o valor desejado no calculo: '))
if operador == '+':
  resultado = num1 + num2
elif operador == '-':
  resultado = num1 - num2
elif operador == '*':
  resultado = num1 * num2
elif operador == '/':
  resultado = num1 / num2
if resultado < 10000:
  print(f'Resultado: {resultado: .0f}')
else:
  print('Parece que alguém não leu as regras.')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3675106325.py in <cell line: 0>()
#       2 # no texto eu pedi ajuda ao GPT, pois nao sabia como podia fazer de um jeito que ficasse bom, pois a linha ficou super reta e poluida.
#       3 # espero não perder pontos
# ----> 4 nome = input('como você se chama calculador?: ')
#       5 print('=' * 50)
#       6 print(f"Bem-vindo(a) {nome}! Aqui é a Calculadora Calculável, sim, ISSO MESMO: C-A-L-C-U-L-A-V-E-L.\n")
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## CALCULADORA2 == ESTAVA TESTANDO OUTRO JEITO

# %%
# Nessa daqui eu fiquei curioso em testar algumas coisas porem eu nao sabia como.
# Então pesquisei e fiz da maneira que eu queria que saisse.
# Caso eu tenha cometido algum erro peço quee me falem.
# quero começar o quanto antes na carreira.

nome = input('como você se chama calculador?: ')
print('=' * 50)
print(f"Bem-vindo(a) {nome}! Aqui é a Calculadora Calculável, sim, ISSO MESMO: C-A-L-C-U-L-A-V-E-L.\n")
print("Aqui existem duas regras:")
print("- Seus cálculos não podem ultrapassar 99999;")
print("- Você só pode usar as operações (+, -, *, /).\n")
print("Bom cálculo!\n")
print('=' * 50)
while True:
 num1 = int(input('Digite o valor desejado no calculo: '))
 operador = input('Escolha o operador: (+, -, *, /)')
 num2 = int(input('Digite o valor desejado no calculo: '))
 if operador == '+':
  resultado = num1 + num2
 elif operador == '-':
  resultado = num1 - num2
 elif operador == '*':
  resultado = num1 * num2
 elif operador == '/':
  resultado = num1 / num2
 else:
    print('operador invalido')
    continue
 if resultado < 10000:
    print(f'Resultado: {resultado: .0f}')
 else:
    print('Parece que alguém não leu as regras.')

continuar = input('Deseja fazer outro calculo? (S/N): ')
if continuar.lower != 's':
 print('Até a proxima')
 break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2412106743.py in <cell line: 0>()
#       4 # quero começar o quanto antes na carreira.
#       5
# ----> 6 nome = input('como você se chama calculador?: ')
#       7 print('=' * 50)
#       8 print(f"Bem-vindo(a) {nome}! Aqui é a Calculadora Calculável, sim, ISSO MESMO: C-A-L-C-U-L-A-V-E-L.\n")
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Nessa daqui eu fiquei curioso em testar algumas coisas porem eu nao sabia como.
# Então pesquisei e fiz da maneira que eu queria que saisse.
# Caso eu tenha cometido algum erro peço quee me falem.
# quero começar o quanto antes na carreira.

nome = input('como você se chama calculador?: ')
print('=' * 50)
print(f"Bem-vindo(a) {nome}! Aqui é a Calculadora Calculável, sim, ISSO MESMO: C-A-L-C-U-L-A-V-E-L.\n")
print("Aqui existem duas regras:")
print("- Seus cálculos não podem ultrapassar 99999;")
print("- Você só pode usar as operações (+, -, *, /).\n")
print("Bom cálculo!\n")
print('=' * 50)
while True:
  try:
   num1 = int(input('Digite o valor desejado no calculo: '))
   operador = input('Escolha o operador: (+, -, *, /)')
   num2 = int(input('Digite o valor desejado no calculo: '))
  except valueError:
   print("Entrada invalida. Por favor insira apenas números. ")
   continue
resultado = 0
if operador == '+':
     resultado = num1 + num2
elif operador == '-':
    resultado = num1 - num2
elif operador == '*':
    resultado = num1 * num2
elif operador == '/':
    resultado = num1 / num2
else:
    print('operador invalido')
if resultado < 10000:
    print(f'Resultado: {resultado: .0f}')
else:
    print('Parece que alguém não leu as regras.')

continuar = input('Deseja fazer outro calculo? (S/N): ')
if continuar.lower != 's':
  print('Até a proxima')
# Out:
# como você se chama calculador?: lçklç
# ==================================================
# Bem-vindo(a) lçklç! Aqui é a Calculadora Calculável, sim, ISSO MESMO: C-A-L-C-U-L-A-V-E-L.
#
# Aqui existem duas regras:
# - Seus cálculos não podem ultrapassar 99999;
# - Você só pode usar as operações (+, -, *, /).
#
# Bom cálculo!
#
# ==================================================
# Digite o valor desejado no calculo: jjlk
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2669592510.py in <cell line: 0>()
#      15   try:
# ---> 16    num1 = int(input('Digite o valor desejado no calculo: '))
#      17    operador = input('Escolha o operador: (+, -, *, /)')
#
# ValueError: invalid literal for int() with base 10: 'jjlk'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2669592510.py in <cell line: 0>()
#      17    operador = input('Escolha o operador: (+, -, *, /)')
#      18    num2 = int(input('Digite o valor desejado no calculo: '))
# ---> 19   except valueError:
#      20    print("Entrada invalida. Por favor insira apenas números. ")
#      21    continue
#
# NameError: name 'valueError' is not defined

# %%
import sys
import datetime

if  len(sys.argv) > 1:
  nome = sys.argv[1]
else :
  nome = "usuario anonimo"
print('=' * 50)
print(f"Bem vindo jogad")
